# %%
import os 
import pathlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string

# %%
##--- Paths

# %%
os.listdir('uploaded-dataset/')
# Out:
# ['articles introductions.txt', 'articles titles.txt']

# %%
input_text_path = 'uploaded-dataset/articles introductions.txt'
labels_text_path = 'uploaded-dataset/articles titles.txt'

# %%
labels_list = []
input_list = []

# %%
with open(labels_text_path,mode='rt',encoding='utf-8') as f:
    labels_list.append(f.read().split('\n'))

# %%
with open(input_text_path,mode='rt',encoding='utf-8') as f:
     input_list.append(f.read().split('\n'))

# %%
labels_list
# Out:
# [['المتحف العربي للفن الحديث',
#   'فيلاجيو مول',
#   'كورنيش الدوحة',
#   'منتجع شاطئ سيلين',
#   'منتجع الغارية',
#   'جزيرة النخل',
#   'مملكة علاء الدين',
#   'شواطيء الخور و فويرط',
#   'الجغرافيا و المناخ',
#   'عدد و تركيبة السكان',
#   'المغرب الموحدة',
#   'معلومات عن قطر',
#   'التاريخ و التسمية',
#   'التقسيم الإداري و الثقافة',
#   'سكان الدوحة',
#   'أين تذهب في قطر ؟ ',
#   'جغرافية مملكة البحرين',
#   'مناخ مملكة البحرين',
#   'الجزر البحرينية',
#   'منتجع جزيرة البنانا',
#   'تطوير منتجع جزيرة البنانا',
#   'رحلات منتجع جزيرة البنانا',
#   'اقتصاد اليابان',
#   'الصناعة اليابانية',
#   'الإسلام في اليابان',
#   'دخول الإسلام إلى اليابان',
#   'القرآن الكريم',
#   'التعليم الإسلامي',
#   'الجمعيات الإسلامية',
#   'علم دولة فلسطين',
#   'حدودها الجغرافية',
#   'كيفية تحضير الحناء',
#   'التخلص من الحناء على الشعر',
#   'وقت الزيارة',
#   'متحف الفن الإسلامي',
#   'البيتزا مارغريتا',
#   'اكتشاف شخصية الرجل',
#   'شخصية الرجل من طريقة حلاقة شعره',
# ...

# %%
len(*labels_list)
# Out:
# 294840

# %%
len(*input_list)
# Out:
# 294840

# %%
df = pd.DataFrame(data= {'Input_Text':pd.Series(*input_list),'Labels':pd.Series(*labels_list)})

# %%
df.head()
# Out:
#                                           Input_Text  \
# 0  و هو يعتبر متحف جديد العهد ، يقدم مجموعة من ال...
# 1  يعتبر فيلاجيو مول من أهم المجمعات التجارية و أ...
# 2  هو المنطقة البحرية الممتدة على مجموعة كيلومترا...
# 3  يعتبر هذا المنتجع من أجمل الأماكن الساحلية الم...
# 4  و هو منتجع مطل على البحر ، و يحوي العديد من أم...
#
#                       Labels
# 0  المتحف العربي للفن الحديث
# 1                فيلاجيو مول
# 2              كورنيش الدوحة
# 3           منتجع شاطئ سيلين
# 4              منتجع الغارية

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294840 entries, 0 to 294839
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Input_Text  294840 non-null  object
#  1   Labels      294840 non-null  object
# dtypes: object(2)
# memory usage: 4.5+ MB
