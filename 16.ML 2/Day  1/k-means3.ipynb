# %% [markdown]
# # Clustering Colors from an Image

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

# %%
# load image
img = plt.imread('peppers.jpg')
#img = plt.imread('rose2.jfif')
plt.imshow(img) #show image
plt.axis('off');

# %% [markdown]
# The image above has 480 pixels in height and 640 pixels in width.  Each pixel has 3 values that represent how much red, green and blue it has. Below you can play with different combinations of RGB to create different colors. In total, you can create $256^3 = 16,777,216$ unique colors.

# %% [markdown]
# img_flat = img.reshape(img.shape[0]*img.shape[1],3)
# print(img_flat.shape)
# img_flat[:5,:]
# img_flat.shape

# %%
img_flat = img.reshape(img.shape[0]*img.shape[1],3)
print(img_flat.shape)
# Out:
# (307200, 3)

# %%
# Question1 Apply k-means Algorithm

kmeans = KMeans(n_clusters=2).fit(img_flat)
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
#Question 2
# loops for each cluster center
#replace kmeans.labels_ with kmeans.cluster_centers_[i]
img_flat2 = img_flat.copy()
kmeans = KMeans(n_clusters=2)
kmeans.fit(img_flat)
for i in np.unique(kmeans.labels_):
    img_flat2[kmeans.labels_==i,:] = kmeans.cluster_centers_[i]

    img2 = img_flat2.reshape(img.shape)
plt.imshow(img2) #show image
plt.axis('off');

# %% [markdown]
# #Question 3 Apply elbow method

# %%
# Question3 
##Apply Elbow
img_flat3 = img_flat.copy()
All_intria = [ ]
S = 1
E = 20
for i in range(S,E):
    Kmeans = KMeans(n_clusters  = i,random_state=9110 , max_iter= 10)
    Kmeans.fit(img_flat)
    
    All_intria.append(Kmeans.inertia_)

plt.plot(range(S,E),All_intria)
plt.show()

# %% [markdown]
# play around with n_clusters

# %%
#Question 2
# loops for each cluster center
#replace kmeans.labels_ with kmeans.cluster_centers_[i]
img_flat2 = img_flat.copy()
kmeans = KMeans(n_clusters=10)
kmeans.fit(img_flat)
for i in np.unique(kmeans.labels_):
    img_flat2[kmeans.labels_==i,:] = kmeans.cluster_centers_[i]

    img2 = img_flat2.reshape(img.shape)
plt.imshow(img2) #show image
plt.axis('off');

# %% [markdown]
# ### play around with max iter

# %%
#Question 2
# loops for each cluster center
#replace kmeans.labels_ with kmeans.cluster_centers_[i]
img_flat2 = img_flat.copy()
kmeans = KMeans(n_clusters=10 , max_iter= 5)
kmeans.fit(img_flat)
for i in np.unique(kmeans.labels_):
    img_flat2[kmeans.labels_==i,:] = kmeans.cluster_centers_[i]

    img2 = img_flat2.reshape(img.shape)
plt.imshow(img2) #show image
plt.axis('off');
x = Kmeans.labels_
unique, counts = np.unique(x, return_counts=True)

print (np.asarray((unique, counts)).T)
# Out:
# [[    0 15050]
#  [    1 16172]
#  [    2 33066]
#  [    3  3081]
#  [    4 18061]
#  [    5 25756]
#  [    6  9118]
#  [    7 21900]
#  [    8 15561]
#  [    9  8468]
#  [   10  6569]
#  [   11 24458]
#  [   12  4925]
#  [   13 11106]
#  [   14 17092]
#  [   15 19662]
#  [   16 15299]
#  [   17 37781]
#  [   18  4075]]

# %%
#Question 2
# loops for each cluster center
#replace kmeans.labels_ with kmeans.cluster_centers_[i]
img_flat2 = img_flat.copy()
kmeans = KMeans(n_clusters=10 , max_iter= 10)
kmeans.fit(img_flat)
for i in np.unique(kmeans.labels_):
    img_flat2[kmeans.labels_==i,:] = kmeans.cluster_centers_[i]

    img2 = img_flat2.reshape(img.shape)
plt.imshow(img2) #show image
plt.axis('off');
x = Kmeans.labels_
unique, counts = np.unique(x, return_counts=True)

print (np.asarray((unique, counts)).T)
# Out:
# [[    0 15050]
#  [    1 16172]
#  [    2 33066]
#  [    3  3081]
#  [    4 18061]
#  [    5 25756]
#  [    6  9118]
#  [    7 21900]
#  [    8 15561]
#  [    9  8468]
#  [   10  6569]
#  [   11 24458]
#  [   12  4925]
#  [   13 11106]
#  [   14 17092]
#  [   15 19662]
#  [   16 15299]
#  [   17 37781]
#  [   18  4075]]

# %%
#Question 2
# loops for each cluster center
#replace kmeans.labels_ with kmeans.cluster_centers_[i]
img_flat2 = img_flat.copy()
kmeans = KMeans(n_clusters=10, max_iter= 100)
kmeans.fit(img_flat)
for i in np.unique(kmeans.labels_):
    img_flat2[kmeans.labels_==i,:] = kmeans.cluster_centers_[i]

    img2 = img_flat2.reshape(img.shape)
plt.imshow(img2) #show image
plt.axis('off');
x = Kmeans.labels_
unique, counts = np.unique(x, return_counts=True)

print (np.asarray((unique, counts)).T)
# Out:
# [[    0 15050]
#  [    1 16172]
#  [    2 33066]
#  [    3  3081]
#  [    4 18061]
#  [    5 25756]
#  [    6  9118]
#  [    7 21900]
#  [    8 15561]
#  [    9  8468]
#  [   10  6569]
#  [   11 24458]
#  [   12  4925]
#  [   13 11106]
#  [   14 17092]
#  [   15 19662]
#  [   16 15299]
#  [   17 37781]
#  [   18  4075]]

# %%
#Question 2
# loops for each cluster center
#replace kmeans.labels_ with kmeans.cluster_centers_[i]
img_flat2 = img_flat.copy()
kmeans = KMeans(n_clusters=10 , max_iter= 1000)
kmeans.fit(img_flat)
for i in np.unique(kmeans.labels_):
    img_flat2[kmeans.labels_==i,:] = kmeans.cluster_centers_[i]

    img2 = img_flat2.reshape(img.shape)
plt.imshow(img2) #show image
plt.axis('off');
x = Kmeans.labels_
unique, counts = np.unique(x, return_counts=True)

print (np.asarray((unique, counts)).T)
# Out:
# [[    0 15050]
#  [    1 16172]
#  [    2 33066]
#  [    3  3081]
#  [    4 18061]
#  [    5 25756]
#  [    6  9118]
#  [    7 21900]
#  [    8 15561]
#  [    9  8468]
#  [   10  6569]
#  [   11 24458]
#  [   12  4925]
#  [   13 11106]
#  [   14 17092]
#  [   15 19662]
#  [   16 15299]
#  [   17 37781]
#  [   18  4075]]

# %% [markdown]
# max iter 10 is enoght

# %% [markdown]
# ### Final use

# %%
img_flat2 = img_flat.copy()
kmeans = KMeans(n_clusters=10 , max_iter= 10)
kmeans.fit(img_flat)
for i in np.unique(kmeans.labels_):
    img_flat2[kmeans.labels_==i,:] = kmeans.cluster_centers_[i]

    img2 = img_flat2.reshape(img.shape)
plt.imshow(img2) #show image
plt.axis('off');
