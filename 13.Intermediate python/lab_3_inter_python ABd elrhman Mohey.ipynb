# %% [markdown]
# # lab 3  data analysis and visualization
#
# **Heart disease** or **Cardiovascular disease (CVD)** is a class of diseases that involve the heart or blood vessels. Cardiovascular diseases are the leading cause of death globally. This is true in all areas of the world except Africa. Together CVD resulted in 17.9 million deaths (32.1%) in 2015.  Deaths, at a given age, from CVD are more common and have been increasing in much of the developing world, while rates have declined in most of the developed world since the 1970s.
#
# So, in this kernel, I have conducted **Exploratory Data Analysis** or **EDA** of the heart disease dataset. **Exploratory Data Analysis** or **EDA** is a critical first step in analyzing a new dataset. The primary objective of EDA is to analyze the data for distribution, outliers and anomalies in the dataset. It enable us to direct specific testing of the hypothesis. It includes analysing the data to find the distribution of data, its main characteristics, identifying patterns and visualizations.  It also provides tools for hypothesis generation by visualizing and understanding the data through graphical representation.

# %% [markdown]
# ### The objectives of the EDA are as follows:-
#
# i. To get an overview of the distribution of the dataset.
#
# ii. Check for missing numerical values, outliers or other anomalies in the dataset.
#
# iii.Discover patterns and relationships between variables in the dataset.

# %% [markdown]
# ### Dataset description
# The dataset contains several columns which are as follows -
#
# - age : age in years
# - sex : (1 = male; 0 = female)
# - cp : chest pain type
# -  trestbps : resting blood pressure (in mm Hg on admission to the hospital)
# - chol : serum cholestoral in mg/dl
# - fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# - restecg : resting electrocardiographic results
# - thalach : maximum heart rate achieved
# - exang : exercise induced angina (1 = yes; 0 = no)
# - oldpeak : ST depression induced by exercise relative to rest
# - slope : the slope of the peak exercise ST segment
# - ca : number of major vessels (0-3) colored by flourosopy
# - thal : 3 = normal; 6 = fixed defect; 7 = reversable defect
# - target : 1 or 0

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
# %matplotlib inline

# %% [markdown]
# ### 1. Import dataset

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### 2. Exploratory data analysis:
#     2.1- Check shape of the dataset
#     2.2- Preview the dataset
#     2.3- Summary of dataset
#     2.4- Dataset description
#     2.5- Check data types of columns
#     2.6- Important points about dataset
#     2.7- Statistical properties of dataset
#     2.8- View column names

# %%
# print the shape
df.shape
# Out:
# (303, 14)

# %%
# preview dataset
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
# summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# check data type
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# statistical properties of dataset
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# View column names
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ###  3- Analysis of target feature variable
#       1- check the unique values
#       2- count the unique values
#       3- print the frequency of each value
#       4- visualize the distribution the target
#       5- frequency distribution of target variable wrt sex

# %%
#check the unique values
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#count the unique values 
df['target'].nunique()
# Out:
# 2

# %%
#print the frequency of each value
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
# df['target'].value_counts()/df.shape[0]

# %%
# visualize the distribution the target
plt.hist(df['target']);

# %%
sns.histplot(df , x = 'target');

# %%
# frequency distribution of target variable wrt sex
df.groupby(['target' , 'sex']).count()
# Out:
#             age   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# target sex
# 0      0     24   24        24    24   24       24       24     24       24
#        1    114  114       114   114  114      114      114    114      114
# 1      0     72   72        72    72   72       72       72     72       72
#        1     93   93        93    93   93       93       93     93       93
#
#             slope   ca  thal
# target sex
# 0      0       24   24    24
#        1      114  114   114
# 1      0       72   72    72
#        1       93   93    93

# %%
df.groupby('sex').count()['target']
# Out:
# sex
# 0     96
# 1    207
# Name: target, dtype: int64

# %% [markdown]
# ### 4- Estimate correlation
#         1- get the correlation between features
#         2- plot a fig. that represent the correlation values between features
#         3- plot a fig  the represent the correlation between features

# %%
# get the correlation between features 
cor = df.corr()
cor
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
# plot a fig. that represent the correlation values between features
plt.figure(figsize=(12,10))
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# plot a fig  the represent the correlation between features
pd.plotting.scatter_matrix(df, alpha=0.2,figsize = (20,20));

# %%
sns.pairplot(df);

# %% [markdown]
# ### 5- Analysis of age
#
#         1. check the unique values
#         2. View statistical summary of age variable
#         3. plot the figure that help to check if the age feature contains outliers
#         4- Visualize distribution of age variable wrt target with boxplot

# %%
## check the unique values
df['age'].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
## View statistical summary of age variable
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
## plot the figure that help to check if the age feature contains outliers
plt.boxplot(df['age']);

# %%
sns.boxplot(data = df , y = 'age');

# %%
#Visualize distribution of age variable wrt target with boxplot
sns.boxplot(data = df , x = 'target' , y = 'age');
