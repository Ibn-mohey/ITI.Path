# %% [markdown]
# ### first question
# Kindly open this web page:
# https://www.premierleague.com/stats/top/players/goals?se=-1
#
# and use Selenium to extract a dataset consists of: <br>
# players names, rank, number of goals, and their nationalities <br>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

# %%
driver = webdriver.Chrome()
url = "https://www.kaggle.com/c/dry-beans-classification-iti-ai-pro-intake01/leaderboard"
driver.get(url)
driver.maximize_window()
test1 = driver.find_elements_by_xpath('//td[@class="competition-leaderboard__td-rank"]')
testlist = []
for p in range(len(testlist)):
    names.append(testlist[p].text)
testlist
# Out:
# []

# %%
print(driver.page_source)
# Out:
# <html lang="en"><head>
#   <title>Dry Beans Classification | Kaggle</title>
#   <meta charset="utf-8">
#   <meta name="robots" content="index, follow">
#   <meta name="description" content="Can you predict the type of a dry bean from its shape features?">
#   <meta name="turbolinks-cache-control" content="no-cache">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#   <meta name="theme-color" content="#008ABC">
# ...

# %%
test1 = driver.find_elements_by_xpath('//a[@class="competition-leaderboard__td-rank"]')
testlist = []
for p in range(len(testlist)):
    names.append(testlist[p].text)

# %%
print(testlist)
# Out:
# []

# %%
#players names

test1 = driver.find_elements_by_xpath('//a[@class="playerName"]')
testlist = []
for p in range(len(testlist)):
    names.append(testlist[p].text)


#rank class="rank"
players = driver.find_elements_by_xpath('//td[@class="rank"]')
ranks = []
for p in range(len(players)):
    ranks.append(players[p].text)
#number of goals mainStat text-centre
players = driver.find_elements_by_xpath('//td[@class="mainStat text-centre"]')
goals = []
for p in range(len(players)):
    goals.append(players[p].text)

#nationalities span playerCountry

players = driver.find_elements_by_xpath('//span[@class="playerCountry"]')
nationalities = []
for p in range(len(players)):
    nationalities.append(players[p].text)

driver.close()

# %%
top20scorrer = pd.DataFrame(list(zip(names,ranks,goals,nationalities)),
                         columns=['Name','Rank','number_of_goals' , 'nationality'])
top20scorrer
# Out:
#                        Name Rank number_of_goals        nationality
# 0              Alan Shearer    1             260            England
# 1              Wayne Rooney    2             208            England
# 2               Andrew Cole    3             187            England
# 3             Sergio Agüero    4             184          Argentina
# 4             Frank Lampard    5             177            England
# 5             Thierry Henry    6             175             France
# 6                Harry Kane    7             166            England
# 7             Robbie Fowler    8             163            England
# 8             Jermain Defoe    9             162            England
# 9              Michael Owen   10             150            England
# 10            Les Ferdinand   11             149            England
# 11         Teddy Sheringham   12             146            England
# 12         Robin van Persie   13             144        Netherlands
# ...

# %%
import pandas as pd
import urllib3  # pip install -i https://pypi.anaconda.org/pypi/simple urllib3
import json
import sys
import warnings

warnings.filterwarnings('ignore')

def data_scraper(competition, types):
    if types == 'public':
        url = 'https://www.kaggle.com/c/{competition}/leaderboard.json?includeBeforeUser=true&includeAfterUser=true'.format(
            competition=competition)
    elif type == 'private':
        url = 'https://www.kaggle.com/c/{competition}/leaderboard.json?includeBeforeUser=true&includeAfterUser=true&type=private'.format(
            competition=competition)
    else:
        print('榜单类型有误，请检查')

    http = urllib3.PoolManager()
    response = http.request('GET', url)
    print('Status Code：' + str(response.status))

    ranks = str(response.data).replace("\\", "")

    return ranks


def data_parser(competition, types='public'):
    ranks0 = data_scraper(competition, types)
    ranks1 = json.loads(ranks0[2:-1])['beforeUser']
    ranks2 = json.loads(ranks0[2:-1])['afterUser']

    ranks = ranks1 + ranks2

    team_list = list(ranks)

    rank_score = pd.DataFrame(columns=['rank', 'teamName', 'entries', 'lastSubmission', 'score'])

    for team in team_list:
        rank = team.get('rank')
        teamName = team.get('teamName')
        entries = team.get('entries')
        lastSubmission = team.get('lastSubmission')
        score = team.get('score')
        rank_score = rank_score.append(
            {'rank': rank, 'teamName': teamName, 'entries': entries, 'lastSubmission': lastSubmission, 'score': score},
            ignore_index=True)

    rank_score = rank_score.dropna()

    return rank_score
data_parser('dry-beans-classification-iti-ai-pro-intake01')
# Out:
# Status Code：200
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-17-dd6c51c5300c> in <module>
#      50
#      51     return rank_score
# ---> 52 data_parser('dry-beans-classification-iti-ai-pro-intake01')
#
# <ipython-input-17-dd6c51c5300c> in data_parser(competition, types)
#      28 def data_parser(competition, types='public'):
#      29     ranks0 = data_scraper(competition, types)
# ---> 30     ranks1 = json.loads(ranks0[2:-1])['beforeUser']
#      31     ranks2 = json.loads(ranks0[2:-1])['afterUser']
#      32
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
types = 'public'
if types == 'public':
    url = 'https://www.kaggle.com/c/dry-beans-classification-iti-ai-pro-intake01/leaderboard'

http = urllib3.PoolManager()
response = http.request('GET', url)
print('Status Code：' + str(response.status))

ranks = str(response.data).replace("\\", "")
ranks
# Out:
# Status Code：200
# ...
